# %%
from utilities import process_all_files_from_directory
import pandas as pd
import numpy as np
import os
# import pyarrow

# %%
Data_Quality_Indicator = 'C:/Users/jkumava/Downloads/PCRM/1008128171/RCP_26/ID_1008128171_Data Quality Indicator.csv'
base_path = os.path.dirname(Data_Quality_Indicator)
comp_id = "ID_1008128171"

# %%
df_import_years = pd.DataFrame( [
	{
		"year" : 2030,
		"active" : 1,
		"table_name" : "damage"
	},
	{
		"year" : 2050,
		"active" : 1,
		"table_name" : "damage"
	},
	{
		"year" : 2035,
		"active" : 1,
		"table_name" : "damage"
	},
	{
		"year" : 2040,
		"active" : 1,
		"table_name" : "damage"
	},
	{
		"year" : 2045,
		"active" : 1,
		"table_name" : "damage"
	},
	{
		"year" : 2025,
		"active" : 1,
		"table_name" : "damage"
	},
	{
		"year" : 2030,
		"active" : 1,
		"table_name" : "global"
	},
	{
		"year" : 2050,
		"active" : 1,
		"table_name" : "global"
	},
	{
		"year" : 2100,
		"active" : 1,
		"table_name" : "global"
	},
	{
		"year" : 2023,
		"active" : 1,
		"table_name" : "damage"
	},
	{
		"year" : 2023,
		"active" : 1,
		"table_name" : "global"
	},
    {
		"year" : 2027,
		"active" : 1,
		"table_name" : "global"
	},
	{
		"year" : 2028,
		"active" : 1,
		"table_name" : "global"
	},
	{
		"year" : 2022,
		"active" : 1,
		"table_name" : "global"
	}
])
df_import_years
# Out:
#     year  active table_name
# 0   2030       1     damage
# 1   2050       1     damage
# 2   2035       1     damage
# 3   2040       1     damage
# 4   2045       1     damage
# 5   2025       1     damage
# 6   2030       1     global
# 7   2050       1     global
# 8   2100       1     global
# 9   2023       1     damage
# 10  2023       1     global
# 11  2027       1     global
# 12  2028       1     global
# 13  2022       1     global

# %%
df_full = pd.read_csv("df_full_calculated.csv")#,engine='pyarrow',dtype_backend='pyarrow')
df_full.head()
# Out:
#   Scenario  sustcompanyid Country        peergroup         hazard_type  Year  \
# 0   RCP2.6     1008128171     ARE  Precious Metals  Coastal Inundation  2022
# 1   RCP2.6     1008128171     ARE  Precious Metals        Cyclone Wind  2022
# 2   RCP2.6     1008128171     ARE  Precious Metals        Extreme Heat  2022
# 3   RCP2.6     1008128171     ARE  Precious Metals        Extreme Wind  2022
# 4   RCP2.6     1008128171     ARE  Precious Metals            Flooding  2022
#
#    sum_hazard_risk  avg_hazard_risk         CompanyName  \
# 0         0.000000         0.000000  Barrick Gold Corp.
# 1         0.000003         0.000003  Barrick Gold Corp.
# 2         0.000000         0.000000  Barrick Gold Corp.
# 3         0.000047         0.000047  Barrick Gold Corp.
# 4         0.000000         0.000000  Barrick Gold Corp.
#
#    count_assets_with_asset_damage_risk  ...  ReplacementCost  Turnover  \
# 0                                    0  ...        1000000.0   2000000
# 1                                    0  ...        1000000.0   2000000
# 2                                    0  ...        1000000.0   2000000
# 3                                    0  ...        1000000.0   2000000
# 4                                    0  ...        1000000.0   2000000
#
#    total_assets_count  clientindustryid  clientindustryname  \
# 0                 583          151019.0     Precious Metals
# 1                 583          151019.0     Precious Metals
# 2                 583          151019.0     Precious Metals
# 3                 583          151019.0     Precious Metals
# 4                 583          151019.0     Precious Metals
#
#    percent_of_assets_in_country  weighted_avg_hazard_risk  weighted_prodloss  \
# 0                      0.001715              0.000000e+00       0.000000e+00
# 1                      0.001715              4.442539e-09       4.286285e-10
# 2                      0.001715              0.000000e+00       4.665946e-06
# 3                      0.001715              7.989708e-08       5.836462e-09
# 4                      0.001715              0.000000e+00       0.000000e+00
#
#    weighted_productive_capacity_loss_days indirect_probability
# 0                                0.000000             0.001993
# 1                                0.053175             0.001993
# 2                              578.854853             0.001988
# 3                                0.724069             0.001993
# 4                                0.000000             0.001993
#
# [5 rows x 25 columns]

# %%
active_import_years = df_import_years.query("active == True and table_name == 'damage'")['year']
active_import_years
# Out:
# 0    2030
# 1    2050
# 2    2035
# 3    2040
# 4    2045
# 5    2025
# 9    2023
# Name: year, dtype: int64

# %%
fc = df_full[df_full['Year'].isin(active_import_years)]
fc = fc.query("(peergroup not in ['Insurance', 'Banks', 'Diversified Financials', 'Real Estate'] ) and Year > 2020 and Year < 2051")

# %%
fc_grouped = fc_grouped = fc.groupby(['sustcompanyid', 'Scenario', 'Country', 'Year']).agg(
    productive_capacity_loss=('productive_capacity_loss', 'sum'),
    country_asset_damage_risk=('avg_hazard_risk', 'sum')
).reset_index()

# %%
import_years =  (2030,2050,2100,2045,2035,2040,2025,2022,2027,2023,2028)

# %%
fc_grouped.head()
# Out:
#    sustcompanyid Scenario Country  Year  productive_capacity_loss  \
# 0     1008128171   RCP2.6     ARE  2023                  0.002724
# 1     1008128171   RCP2.6     ARE  2025                  0.002724
# 2     1008128171   RCP2.6     ARE  2030                  0.002724
# 3     1008128171   RCP2.6     ARE  2035                  0.002724
# 4     1008128171   RCP2.6     ARE  2040                  0.002724
#
#    country_asset_damage_risk
# 0                   0.000049
# 1                   0.000050
# 2                   0.000051
# 3                   0.000052
# 4                   0.000053

# %%
# Correct_code

# fmi_df = pd.read_csv(base_path+f'/{comp_id}_First Mile Indicator.csv',engine='pyarrow',dtype_backend='pyarrow')

# fmi_df['entity_id'] = fmi_df['CompanyID'].str.replace('ID_','').astype(int)
# fmi_df['FMI'] = pd.to_numeric(fmi_df['FMI'], errors='coerce')

# fmi_df = fmi_df[fmi_df['Year'].isin(import_years)].reset_index(drop=True)
# fmi_df

# %%
fmi_df = pd.read_csv(base_path+f'/{comp_id}_First Mile Indicator.csv')
fmi_df['entity_id'] = fmi_df['CompanyID'].str.replace('ID_','').astype(int)
fmi_df['FMI'] = pd.to_numeric(fmi_df['FMI'], errors='coerce')

fmi_df = fmi_df[fmi_df['Year'].isin(import_years)].reset_index(drop=True)
fmi_df = fmi_df.rename(columns = {'country': 'Country', "year" : "Year" ,'scenario_code' : 'Scenario','fmi':'FMI'} )

fmi_df
# Out:
#     Scenario      CompanyID         CompanyName Country  Year       FMI  \
# 0     RCP2.6  ID_1008128171  Barrick Gold Corp.     ARE  2022  0.001993
# 1     RCP2.6  ID_1008128171  Barrick Gold Corp.     ARE  2023  0.002134
# 2     RCP2.6  ID_1008128171  Barrick Gold Corp.     ARE  2025  0.002413
# 3     RCP2.6  ID_1008128171  Barrick Gold Corp.     ARE  2027  0.002793
# 4     RCP2.6  ID_1008128171  Barrick Gold Corp.     ARE  2028  0.002981
# ..       ...            ...                 ...     ...   ...       ...
# 479   RCP2.6  ID_1008128171  Barrick Gold Corp.     ZMB  2035  0.009765
# 480   RCP2.6  ID_1008128171  Barrick Gold Corp.     ZMB  2040  0.010616
# 481   RCP2.6  ID_1008128171  Barrick Gold Corp.     ZMB  2045  0.011426
# 482   RCP2.6  ID_1008128171  Barrick Gold Corp.     ZMB  2050  0.012038
# 483   RCP2.6  ID_1008128171  Barrick Gold Corp.     ZMB  2100  0.012292
#
#       entity_id
# 0    1008128171
# 1    1008128171
# 2    1008128171
# 3    1008128171
# 4    1008128171
# ..          ...
# 479  1008128171
# 480  1008128171
# 481  1008128171
# 482  1008128171
# 483  1008128171
#
# [484 rows x 7 columns]

# %%
p = fmi_df[['entity_id','Scenario', 'Country', 'Year', 'FMI']].copy()

# %%
p = p.merge(fc_grouped, left_on=['entity_id', 'Country', 'Year', 'Scenario'], right_on=['sustcompanyid', 'Country', 'Year', 'Scenario'])

# %%
p['indirect_probability'] = p['FMI'] - p['productive_capacity_loss'] * p['FMI']

# %%
final_result = p[['entity_id', 'Year', 'Country', 'Scenario', 'FMI', 'country_asset_damage_risk', 'productive_capacity_loss', 'indirect_probability']]

# %%
final_result.to_csv('p_calculated.csv',index=False)

# %%
# z = p[['entity_id', 'Year', 'Country', 'Scenario', 'indirect_probability']]
# z['lead_year'] = z.groupby(['entity_id', 'Scenario', 'Country'])['Year'].shift(-1)
# z['lead_indirect_probability'] = z.groupby(['entity_id', 'Scenario', 'Country'])['indirect_probability'].shift(-1)

# %%
# interp_country_indirect_probability_set = interp_country_indirect_probability_set.rename(
#     columns={'interp_year': 'phys_year', 'interp_value': 'interp_indirect_probability'}
# )
# interp_country_indirect_probability_set = interp_country_indirect_probability_set.drop_duplicates(subset=['country', 'entity_id', 'scenario_code', 'phys_year']).reset_index(drop=True)
# interp_country_indirect_probability_set

# %%
# interp_country_indirect_probability_set[interp_country_indirect_probability_set['country']=='ARE']

# %%
'''select sustcompanyid , revenue_avg_usd , gppe_avg_usd
        from xdi_input.company_global_ppe  
'''
company_global_ppe = pd.read_csv('C:/Users/jkumava/Downloads/PCRM/company_global_ppe_202407111106.csv')
company_global_ppe = company_global_ppe[company_global_ppe['fl_deleted']!=True][['sustcompanyid' , 'revenue_avg_usd' , 'gppe_avg_usd']]
company_global_ppe
# Out:
#        sustcompanyid  revenue_avg_usd  gppe_avg_usd
# 0         2000140868              NaN  2.087653e+07
# 1         1008049895     4.827023e+09  2.286134e+09
# 2         1008177948     2.672657e+09  1.771314e+09
# 3         2001722369              NaN  8.221802e+06
# 4         2004493237              NaN  2.191915e+08
# ...              ...              ...           ...
# 46718     2000505558              NaN  2.595591e+08
# 46719     2000181128              NaN  1.734592e+05
# 46720     2001710123              NaN  2.846011e+07
# 46721     2001226080              NaN  1.342919e+05
# 46722     2009598471              NaN  6.697105e+05
#
# [46723 rows x 3 columns]

# %%
# def get_interpolation(start_year, end_year, start_val, end_val):
#     years = np.arange(start_year, end_year + 1)
#     print(len(years))
#     if start_val != end_val:
#         values = np.linspace(start_val, end_val, len(years))
#     else:
#         values = np.full(len(years), start_val)
#     return pd.DataFrame({'interp_year': years, 'interp_value': values})

# %%
def get_interpolation(start_year, end_year, start_val, end_val):
    if start_year <= end_year:
        years = np.arange(start_year, end_year + 1)
        if start_val != end_val:
            values = np.linspace(start_val, end_val, len(years))
        else:
            values = np.full(len(years), start_val)
        return pd.DataFrame({'interp_year': years, 'interp_value': values})
    else:
        return pd.DataFrame()

# %% [markdown]
# ## xdi_processing.udf_get_damage_interpolated_per_entity( entity_id)

# %%
p = p.rename(columns= {'productive_capacity_loss':'country_productive_capacity_loss'})

# %%
country_asset_damage_risk = p.copy()
country_asset_damage_risk['lead_year'] = country_asset_damage_risk.groupby(['entity_id', 'Scenario', 'Country'])['Year'].shift(-1)
country_asset_damage_risk['lead_country_asset_damage_risk'] = country_asset_damage_risk.groupby(['entity_id', 'Scenario', 'Country'])['country_asset_damage_risk'].shift(-1)

# %%
p.head()
# Out:
#     entity_id Scenario Country  Year       FMI  sustcompanyid  \
# 0  1008128171   RCP2.6     ARE  2023  0.002134     1008128171
# 1  1008128171   RCP2.6     ARE  2025  0.002413     1008128171
# 2  1008128171   RCP2.6     ARE  2030  0.003351     1008128171
# 3  1008128171   RCP2.6     ARE  2035  0.005072     1008128171
# 4  1008128171   RCP2.6     ARE  2040  0.006466     1008128171
#
#    country_productive_capacity_loss  country_asset_damage_risk  \
# 0                          0.002724                   0.000049
# 1                          0.002724                   0.000050
# 2                          0.002724                   0.000051
# 3                          0.002724                   0.000052
# 4                          0.002724                   0.000053
#
#    indirect_probability
# 0              0.002128
# 1              0.002407
# 2              0.003342
# 3              0.005058
# 4              0.006449

# %%
interp_country_asset_damage_risk_set = pd.concat([
    get_interpolation(row['Year'], row['lead_year'] if row['lead_year'] is not None else row['Year'],
                      row['country_asset_damage_risk'], row['lead_country_asset_damage_risk'] if row['lead_country_asset_damage_risk'] is not None else row['country_asset_damage_risk'])
    .assign(entity_id=row['entity_id'], scenario_code=row['Scenario'], country=row['Country'])
    for _, row in country_asset_damage_risk.iterrows()
])

# %%
interp_country_asset_damage_risk_set = interp_country_asset_damage_risk_set.rename(
    columns={'interp_year': 'phys_year', 'interp_value': 'interp_country_asset_damage_risk'}
)
interp_country_asset_damage_risk_set = interp_country_asset_damage_risk_set.drop_duplicates(subset=['country', 'entity_id', 'scenario_code', 'phys_year']).reset_index(drop=True)
interp_country_asset_damage_risk_set
# Out:
#       phys_year  interp_country_asset_damage_risk   entity_id scenario_code  \
# 0        2023.0                          0.000049  1008128171        RCP2.6
# 1        2024.0                          0.000050  1008128171        RCP2.6
# 2        2025.0                          0.000050  1008128171        RCP2.6
# 3        2026.0                          0.000050  1008128171        RCP2.6
# 4        2027.0                          0.000050  1008128171        RCP2.6
# ...         ...                               ...         ...           ...
# 1227     2046.0                          0.000084  1008128171        RCP2.6
# 1228     2047.0                          0.000087  1008128171        RCP2.6
# 1229     2048.0                          0.000091  1008128171        RCP2.6
# 1230     2049.0                          0.000094  1008128171        RCP2.6
# 1231     2050.0                          0.000098  1008128171        RCP2.6
#
#      country
# 0        ARE
# 1        ARE
# 2        ARE
# 3        ARE
# 4        ARE
# ...      ...
# 1227     ZMB
# 1228     ZMB
# 1229     ZMB
# 1230     ZMB
# 1231     ZMB
#
# [1232 rows x 5 columns]

# %%
country_productive_capacity_loss = p.copy()
country_productive_capacity_loss['lead_year'] = country_productive_capacity_loss.groupby(['entity_id', 'Scenario', 'Country'])['Year'].shift(-1)
country_productive_capacity_loss['lead_country_productive_capacity_loss'] = country_productive_capacity_loss.groupby(['entity_id', 'Scenario', 'Country'])['country_productive_capacity_loss'].shift(-1)

# Step 2: Apply the get_interpolation function and concatenate results
interp_country_productive_capacity_loss_set = pd.concat([
    get_interpolation(
        row['Year'], 
        row['lead_year'] if row['lead_year'] is not None else row['Year'],
        row['country_productive_capacity_loss'], 
        row['lead_country_productive_capacity_loss'] if row['lead_country_productive_capacity_loss'] is not None else row['country_productive_capacity_loss']
    ).assign(entity_id=row['entity_id'], scenario_code=row['Scenario'], country=row['Country'])
    for _, row in country_productive_capacity_loss.iterrows()
])

# %%
interp_country_productive_capacity_loss_set.columns
# Out:
# Index(['interp_year', 'interp_value', 'entity_id', 'scenario_code', 'country'], dtype='object')

# %%
country_productive_capacity_loss.columns
# Out:
# Index(['entity_id', 'Scenario', 'Country', 'Year', 'FMI', 'sustcompanyid',
#        'country_productive_capacity_loss', 'country_asset_damage_risk',
#        'indirect_probability', 'lead_year',
#        'lead_country_productive_capacity_loss'],
#       dtype='object')

# %%
interp_country_productive_capacity_loss_set = interp_country_productive_capacity_loss_set.merge(
    country_productive_capacity_loss[['entity_id', 'Scenario', 'Country', 'Year', 'lead_year']],
    left_on=['entity_id', 'scenario_code', 'country', 'interp_year'],
    right_on=['entity_id', 'Scenario', 'Country', 'Year'],
    how='left'
)

# %%
interp_country_productive_capacity_loss_set
# Out:
#       interp_year  interp_value   entity_id scenario_code country Scenario  \
# 0          2023.0      0.002724  1008128171        RCP2.6     ARE   RCP2.6
# 1          2024.0      0.002724  1008128171        RCP2.6     ARE      NaN
# 2          2025.0      0.002724  1008128171        RCP2.6     ARE   RCP2.6
# 3          2025.0      0.002724  1008128171        RCP2.6     ARE   RCP2.6
# 4          2026.0      0.002724  1008128171        RCP2.6     ARE      NaN
# ...           ...           ...         ...           ...     ...      ...
# 1447       2046.0      0.000049  1008128171        RCP2.6     ZMB      NaN
# 1448       2047.0      0.000053  1008128171        RCP2.6     ZMB      NaN
# 1449       2048.0      0.000058  1008128171        RCP2.6     ZMB      NaN
# 1450       2049.0      0.000062  1008128171        RCP2.6     ZMB      NaN
# 1451       2050.0      0.000066  1008128171        RCP2.6     ZMB   RCP2.6
#
#      Country    Year  lead_year
# 0        ARE  2023.0     2025.0
# 1        NaN     NaN        NaN
# 2        ARE  2025.0     2030.0
# 3        ARE  2025.0     2030.0
# 4        NaN     NaN        NaN
# ...      ...     ...        ...
# 1447     NaN     NaN        NaN
# 1448     NaN     NaN        NaN
# 1449     NaN     NaN        NaN
# 1450     NaN     NaN        NaN
# 1451     ZMB  2050.0        NaN
#
# [1452 rows x 9 columns]

# %%
interp_country_productive_capacity_loss_set = interp_country_productive_capacity_loss_set[
    (interp_country_productive_capacity_loss_set['lead_year'].isnull()) | 
    (interp_country_productive_capacity_loss_set['lead_year'] != interp_country_productive_capacity_loss_set['interp_year'])
]

# %%
interp_country_productive_capacity_loss_set = interp_country_productive_capacity_loss_set.drop(columns=['Year', 'lead_year','Country']).drop_duplicates(subset=['country', 'entity_id', 'scenario_code', 'interp_year']).reset_index(drop=True)
interp_country_productive_capacity_loss_set
# Out:
#       interp_year  interp_value   entity_id scenario_code country Scenario
# 0          2023.0      0.002724  1008128171        RCP2.6     ARE   RCP2.6
# 1          2024.0      0.002724  1008128171        RCP2.6     ARE      NaN
# 2          2025.0      0.002724  1008128171        RCP2.6     ARE   RCP2.6
# 3          2026.0      0.002724  1008128171        RCP2.6     ARE      NaN
# 4          2027.0      0.002724  1008128171        RCP2.6     ARE      NaN
# ...           ...           ...         ...           ...     ...      ...
# 1227       2046.0      0.000049  1008128171        RCP2.6     ZMB      NaN
# 1228       2047.0      0.000053  1008128171        RCP2.6     ZMB      NaN
# 1229       2048.0      0.000058  1008128171        RCP2.6     ZMB      NaN
# 1230       2049.0      0.000062  1008128171        RCP2.6     ZMB      NaN
# 1231       2050.0      0.000066  1008128171        RCP2.6     ZMB   RCP2.6
#
# [1232 rows x 6 columns]

# %%
interp_country_productive_capacity_loss_set = interp_country_productive_capacity_loss_set.rename(
    columns={'interp_year': 'phys_year', 'interp_value': 'interp_country_productive_capacity_loss'}
)[['entity_id', 'scenario_code', 'country', 'phys_year', 'interp_country_productive_capacity_loss']]

# %%
interp_country_productive_capacity_loss_set['phys_year'] = interp_country_productive_capacity_loss_set['phys_year'].astype(int)

# %%
interp_country_productive_capacity_loss_set[interp_country_productive_capacity_loss_set['country']=='ARE']
# Out:
#      entity_id scenario_code country  phys_year  \
# 0   1008128171        RCP2.6     ARE       2023
# 1   1008128171        RCP2.6     ARE       2024
# 2   1008128171        RCP2.6     ARE       2025
# 3   1008128171        RCP2.6     ARE       2026
# 4   1008128171        RCP2.6     ARE       2027
# 5   1008128171        RCP2.6     ARE       2028
# 6   1008128171        RCP2.6     ARE       2029
# 7   1008128171        RCP2.6     ARE       2030
# 8   1008128171        RCP2.6     ARE       2031
# 9   1008128171        RCP2.6     ARE       2032
# 10  1008128171        RCP2.6     ARE       2033
# 11  1008128171        RCP2.6     ARE       2034
# 12  1008128171        RCP2.6     ARE       2035
# 13  1008128171        RCP2.6     ARE       2036
# 14  1008128171        RCP2.6     ARE       2037
# 15  1008128171        RCP2.6     ARE       2038
# 16  1008128171        RCP2.6     ARE       2039
# 17  1008128171        RCP2.6     ARE       2040
# 18  1008128171        RCP2.6     ARE       2041
# 19  1008128171        RCP2.6     ARE       2042
# 20  1008128171        RCP2.6     ARE       2043
# 21  1008128171        RCP2.6     ARE       2044
# 22  1008128171        RCP2.6     ARE       2045
# 23  1008128171        RCP2.6     ARE       2046
# 24  1008128171        RCP2.6     ARE       2047
# 25  1008128171        RCP2.6     ARE       2048
# 26  1008128171        RCP2.6     ARE       2049
# 27  1008128171        RCP2.6     ARE       2050
#
#     interp_country_productive_capacity_loss
# 0                                  0.002724
# 1                                  0.002724
# 2                                  0.002724
# 3                                  0.002724
# 4                                  0.002724
# 5                                  0.002724
# 6                                  0.002724
# 7                                  0.002724
# 8                                  0.002724
# 9                                  0.002724
# 10                                 0.002724
# 11                                 0.002724
# 12                                 0.002724
# 13                                 0.002724
# 14                                 0.002724
# 15                                 0.002724
# 16                                 0.002724
# 17                                 0.002724
# 18                                 0.002724
# 19                                 0.002724
# 20                                 0.002724
# 21                                 0.002724
# 22                                 0.002724
# 23                                 0.002724
# 24                                 0.002724
# 25                                 0.002724
# 26                                 0.002724
# 27                                 0.002724

# %%
# first_mile_indicator DataFrame
first_mile_indicator = p.rename(columns = {'Country':'country' ,"Year" : "year"    
}).copy()
first_mile_indicator['lead_year'] = first_mile_indicator.groupby(['entity_id', 'Scenario', 'country'])['year'].shift(-1)
first_mile_indicator['lead_fmi'] = first_mile_indicator.groupby(['entity_id', 'Scenario', 'country'])['FMI'].shift(-1)

# interp_fmi_treated_set DataFrame
interp_fmi_treated_set = pd.concat([
    get_interpolation(row['year'], row['lead_year'] if row['lead_year'] is not None else row['year'],
                      row['FMI'], row['lead_fmi'] if row['lead_fmi'] is not None else row['fmi'])
    .assign(entity_id=row['entity_id'], scenario_code=row['Scenario'], country=row['country'])
    for _, row in first_mile_indicator.iterrows()
])
interp_fmi_treated_set = interp_fmi_treated_set.rename(
    columns={'interp_year': 'phys_year', 'interp_value': 'interp_FMI'}
)
interp_fmi_treated_set = interp_fmi_treated_set.drop_duplicates(subset=['country', 'entity_id', 'scenario_code', 'phys_year']).reset_index(drop=True)
interp_fmi_treated_set
# Out:
#       phys_year  interp_FMI   entity_id scenario_code country
# 0        2023.0    0.002134  1008128171        RCP2.6     ARE
# 1        2024.0    0.002274  1008128171        RCP2.6     ARE
# 2        2025.0    0.002413  1008128171        RCP2.6     ARE
# 3        2026.0    0.002601  1008128171        RCP2.6     ARE
# 4        2027.0    0.002788  1008128171        RCP2.6     ARE
# ...         ...         ...         ...           ...     ...
# 1227     2046.0    0.011549  1008128171        RCP2.6     ZMB
# 1228     2047.0    0.011671  1008128171        RCP2.6     ZMB
# 1229     2048.0    0.011794  1008128171        RCP2.6     ZMB
# 1230     2049.0    0.011916  1008128171        RCP2.6     ZMB
# 1231     2050.0    0.012038  1008128171        RCP2.6     ZMB
#
# [1232 rows x 5 columns]

# %% [markdown]
# ## Need confirmation that will be is from DB or from XDI?

# %%
company_segmented_country_averages = pd.read_csv('C:/Users/jkumava/Downloads/PCRM/company_segmented_country_averages_202407141433.csv')
company_segmented_country_averages = company_segmented_country_averages[company_segmented_country_averages ['fl_deleted']!=True].reset_index(drop=True)
company_segmented_country_averages.head()
# Out:
#    sustcompanyid segment_data_point iso3  country_segmented_avg_usd  \
# 0     1012672201      Total Revenue  BMU               2.204246e+08
# 1     1012672201      Total Revenue  GBR               1.020541e+09
# 2     1012672201      Total Revenue  IRL               1.195213e+09
# 3     1012672201      Total Revenue  USA               2.747256e+09
# 4     1008262227       Total Assets  CHN               2.304621e+08
#
#                 dt_created               dt_updated  fl_deleted
# 0  2024-01-15 10:12:38.789  2024-02-01 08:40:20.466         NaN
# 1  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 2  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 3  2023-07-21 12:22:46.545  2024-03-27 13:44:15.137         NaN
# 4  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN

# %%
company_segmented_country_averages[company_segmented_country_averages['sustcompanyid'] == 1008128171]
# Out:
#       sustcompanyid segment_data_point iso3  country_segmented_avg_usd  \
# 1015     1008128171       Total Assets  ARG               2.091447e+09
# 1016     1008128171       Total Assets  CAN               6.678748e+08
# 1017     1008128171       Total Assets  CHL               2.635709e+09
# 1018     1008128171       Total Assets  CIV               2.790496e+08
# 1019     1008128171       Total Assets  COD               4.112607e+09
# 1020     1008128171       Total Assets  DOM               6.073788e+09
# 1021     1008128171       Total Assets  MLI               5.799777e+09
# 1022     1008128171       Total Assets  PAK               9.330023e+08
# 1023     1008128171       Total Assets  PER               1.686161e+08
# 1024     1008128171       Total Assets  PNG               4.471623e+08
# 1025     1008128171       Total Assets  SAU               5.036560e+08
# 1026     1008128171       Total Assets  TZA               2.388953e+09
# 1027     1008128171       Total Assets  USA               2.183621e+10
# 1028     1008128171       Total Assets  ZMB               2.415254e+09
# 1029     1008128171      Total Revenue  ARG               3.847010e+08
# 1030     1008128171      Total Revenue  CAN               3.351664e+08
# 1031     1008128171      Total Revenue  CIV               4.429820e+08
# 1032     1008128171      Total Revenue  DOM               1.587345e+09
# 1033     1008128171      Total Revenue  MLI               1.316959e+09
# 1034     1008128171      Total Revenue  PER               1.154748e+08
# 1035     1008128171      Total Revenue  PNG               1.583064e+08
# 1036     1008128171      Total Revenue  TZA               1.159394e+09
# 1037     1008128171      Total Revenue  USA               6.439749e+09
# 1038     1008128171      Total Revenue  ZMB               8.983666e+08
#
#                    dt_created               dt_updated  fl_deleted
# 1015  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1016  2023-07-21 12:22:46.545  2024-03-05 11:47:06.875         NaN
# 1017  2023-07-21 12:22:46.545  2024-03-22 16:24:21.462         NaN
# 1018  2023-07-21 12:22:46.545  2024-03-27 13:44:15.137         NaN
# 1019  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1020  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1021  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1022  2024-01-15 10:12:38.789  2024-02-01 08:40:20.466         NaN
# 1023  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1024  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1025  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1026  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1027  2023-07-21 12:22:46.545  2024-03-27 13:44:15.137         NaN
# 1028  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1029  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1030  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1031  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1032  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1033  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1034  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1035  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1036  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1037  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN
# 1038  2023-07-21 12:22:46.545  2024-02-01 08:40:20.466         NaN

# %%
asset_country_averages = company_segmented_country_averages[
    (company_segmented_country_averages['segment_data_point'] == 'Total Assets')][['sustcompanyid', 'iso3', 'country_segmented_avg_usd']]
asset_country_averages
# Out:
#         sustcompanyid iso3  country_segmented_avg_usd
# 4          1008262227  CHN               2.304621e+08
# 5          1008262227  USA               1.252210e+08
# 29         2001089921  USA               4.879108e+06
# 30         1008130834  AUS               1.344329e+06
# 31         1008130834  BRA               1.519616e+06
# ...               ...  ...                        ...
# 782713     2015315261  TWN               2.283954e+07
# 782714     2015315261  USA               1.675626e+09
# 783100     2015457395  CAN               2.877411e+07
# 783101     2015457395  ISR               4.333659e+07
# 783328     2008804426  USA               2.865000e+04
#
# [237804 rows x 3 columns]

# %%
revenue_country_averages = company_segmented_country_averages[
    (company_segmented_country_averages['segment_data_point'] == 'Total Revenue')][['sustcompanyid', 'iso3', 'country_segmented_avg_usd']]
revenue_country_averages = revenue_country_averages.rename(columns={'country_segmented_avg_usd': 'avg_country_revenue_usd'})
revenue_country_averages
# Out:
#         sustcompanyid iso3  avg_country_revenue_usd
# 0          1012672201  BMU             2.204246e+08
# 1          1012672201  GBR             1.020541e+09
# 2          1012672201  IRL             1.195213e+09
# 3          1012672201  USA             2.747256e+09
# 6          1008262227  AUS             6.135508e+05
# ...               ...  ...                      ...
# 783324     2013352512  SAU             4.280366e+05
# 783325     2013352512  TUR             3.853849e+05
# 783326     2013352512  TWN             4.817194e+06
# 783327     2013352512  USA             1.091376e+07
# 783329     2000896577  ITA             2.006981e+08
#
# [545526 rows x 3 columns]

# %%
assets_and_revenue_averages = pd.merge(
    asset_country_averages,
    revenue_country_averages,
    on=['sustcompanyid', 'iso3'],
    how='inner'
)
assets_and_revenue_averages
# Out:
#         sustcompanyid iso3  country_segmented_avg_usd  avg_country_revenue_usd
# 0          1008262227  CHN               2.304621e+08             5.598191e+07
# 1          1008262227  USA               1.252210e+08             1.541918e+07
# 2          1008130834  AUS               1.344329e+06             4.664692e+06
# 3          1008130834  BRA               1.519616e+06             5.529763e+06
# 4          1008130834  CAN               1.002330e+08             5.731637e+06
# ...               ...  ...                        ...                      ...
# 212119     2015315261  TUR               2.665958e+06             9.465449e+05
# 212120     2015315261  TWN               2.283954e+07             8.109148e+06
# 212121     2015315261  USA               1.675626e+09             3.516189e+09
# 212122     2015457395  CAN               2.877411e+07             5.442902e+05
# 212123     2015457395  ISR               4.333659e+07             6.588738e+03
#
# [212124 rows x 4 columns]

# %%
global_assets_and_revenue_averages = assets_and_revenue_averages.groupby('sustcompanyid')['country_segmented_avg_usd'].sum().reset_index()
global_assets_and_revenue_averages = global_assets_and_revenue_averages.rename(columns={'country_segmented_avg_usd': 'global_assets_country_segmented_avg_usd'})

# %%
global_assets_and_revenue_averages
# Out:
#        sustcompanyid  global_assets_country_segmented_avg_usd
# 0         1007896773                             3.961547e+10
# 1         1007896917                             2.658466e+09
# 2         1007896995                             4.295158e+11
# 3         1007897253                             4.288860e+10
# 4         1007897295                             3.233720e+12
# ...              ...                                      ...
# 17019     2015315261                             2.084026e+09
# 17020     2015415325                             3.025755e+07
# 17021     2015438304                             1.087934e+07
# 17022     2015457395                             7.211070e+07
# 17023     2015483645                             1.548400e+07
#
# [17024 rows x 2 columns]

# %%
assets_and_revenue_averages_final = pd.merge(
    assets_and_revenue_averages,
    global_assets_and_revenue_averages,
    on='sustcompanyid',
    how='inner'
)

# %%
assets_and_revenue_averages_final['avg_country_asset_proportion'] = (
    assets_and_revenue_averages_final['country_segmented_avg_usd'] / 
    assets_and_revenue_averages_final['global_assets_country_segmented_avg_usd']
)

# %%
assets_and_revenue_averages_final
# Out:
#         sustcompanyid iso3  country_segmented_avg_usd  \
# 0          1008262227  CHN               2.304621e+08
# 1          1008262227  USA               1.252210e+08
# 2          1008130834  AUS               1.344329e+06
# 3          1008130834  BRA               1.519616e+06
# 4          1008130834  CAN               1.002330e+08
# ...               ...  ...                        ...
# 212119     2015315261  TUR               2.665958e+06
# 212120     2015315261  TWN               2.283954e+07
# 212121     2015315261  USA               1.675626e+09
# 212122     2015457395  CAN               2.877411e+07
# 212123     2015457395  ISR               4.333659e+07
#
#         avg_country_revenue_usd  global_assets_country_segmented_avg_usd  \
# 0                  5.598191e+07                             3.556832e+08
# 1                  1.541918e+07                             3.556832e+08
# 2                  4.664692e+06                             1.142317e+09
# 3                  5.529763e+06                             1.142317e+09
# 4                  5.731637e+06                             1.142317e+09
# ...                         ...                                      ...
# 212119             9.465449e+05                             2.084026e+09
# 212120             8.109148e+06                             2.084026e+09
# 212121             3.516189e+09                             2.084026e+09
# 212122             5.442902e+05                             7.211070e+07
# 212123             6.588738e+03                             7.211070e+07
#
#         avg_country_asset_proportion
# 0                           0.647942
# 1                           0.352058
# 2                           0.001177
# 3                           0.001330
# 4                           0.087745
# ...                              ...
# 212119                      0.001279
# 212120                      0.010959
# 212121                      0.804033
# 212122                      0.399027
# 212123                      0.600973
#
# [212124 rows x 6 columns]

# %%
assets_and_revenue_averages_final.columns
# Out:
# Index(['sustcompanyid', 'iso3', 'country_segmented_avg_usd',
#        'avg_country_revenue_usd', 'global_assets_country_segmented_avg_usd',
#        'avg_country_asset_proportion'],
#       dtype='object')

# %%
df = interp_country_asset_damage_risk_set.merge(
    interp_country_productive_capacity_loss_set,
    on=['entity_id', 'scenario_code', 'country', 'phys_year'],
    how='outer',
    suffixes=('_ias', '_ips') 
).merge(
    interp_fmi_treated_set,
    on=['entity_id', 'scenario_code', 'country', 'phys_year'],
    how='outer',
    suffixes=('', '_iis')
).merge(
    assets_and_revenue_averages_final,
    left_on=['entity_id', 'country'],
    right_on=['sustcompanyid', 'iso3'],
    how='left'
).merge(
    company_global_ppe,
    left_on='entity_id',
    right_on='sustcompanyid',
    how='left'
)

# %%
assets_and_revenue_averages_final[assets_and_revenue_averages_final['sustcompanyid']==1008128171]
# Out:
#      sustcompanyid iso3  country_segmented_avg_usd  avg_country_revenue_usd  \
# 361     1008128171  ARG               2.091447e+09             3.847010e+08
# 362     1008128171  CAN               6.678748e+08             3.351664e+08
# 363     1008128171  CIV               2.790496e+08             4.429820e+08
# 364     1008128171  DOM               6.073788e+09             1.587345e+09
# 365     1008128171  MLI               5.799777e+09             1.316959e+09
# 366     1008128171  PER               1.686161e+08             1.154748e+08
# 367     1008128171  PNG               4.471623e+08             1.583064e+08
# 368     1008128171  TZA               2.388953e+09             1.159394e+09
# 369     1008128171  USA               2.183621e+10             6.439749e+09
# 370     1008128171  ZMB               2.415254e+09             8.983666e+08
#
#      global_assets_country_segmented_avg_usd  avg_country_asset_proportion
# 361                             4.216814e+10                      0.049598
# 362                             4.216814e+10                      0.015838
# 363                             4.216814e+10                      0.006618
# 364                             4.216814e+10                      0.144037
# 365                             4.216814e+10                      0.137539
# 366                             4.216814e+10                      0.003999
# 367                             4.216814e+10                      0.010604
# 368                             4.216814e+10                      0.056653
# 369                             4.216814e+10                      0.517837
# 370                             4.216814e+10                      0.057277

# %%
df['expected_indirect_loss_amount_series_undiscounted'] = np.where(
    (df['revenue_avg_usd'] < 0) | (df['gppe_avg_usd'] < 0) | (df['avg_country_revenue_usd'] < 0), 
    np.nan, 
    (df['interp_FMI'] - df['interp_country_productive_capacity_loss'] * df['interp_FMI']) * df['avg_country_revenue_usd']
)

df['expected_indirect_loss_amount_series_discounted'] = df['expected_indirect_loss_amount_series_undiscounted'] / (1.07**(df['phys_year'] - 2021))

df['expected_revenue_loss_amount_series_undiscounted'] = np.where(
    (df['revenue_avg_usd'] < 0) | (df['gppe_avg_usd'] < 0) | (df['avg_country_revenue_usd'] < 0), 
    np.nan, 
    df['interp_country_productive_capacity_loss'] * df['avg_country_revenue_usd']
)

df['expected_revenue_loss_amount_series_discounted'] = df['expected_revenue_loss_amount_series_undiscounted'] / (1.07**(df['phys_year'] - 2021))

df['expected_asset_damage_loss_amount_series_undiscounted'] = np.where(
    (df['revenue_avg_usd'] < 0) | (df['gppe_avg_usd'] < 0), 
    np.nan, 
    df['interp_country_asset_damage_risk'] * df['gppe_avg_usd'] * df['avg_country_asset_proportion']
)

df['expected_asset_damage_loss_amount_series_discounted'] = df['expected_asset_damage_loss_amount_series_undiscounted'] / (1.07**(df['phys_year'] - 2021))

# %%
final_df = df[[
    'entity_id', 'scenario_code', 'phys_year', 'country',
    'expected_indirect_loss_amount_series_undiscounted',
    'expected_indirect_loss_amount_series_discounted',
    'expected_revenue_loss_amount_series_undiscounted',
    'expected_revenue_loss_amount_series_discounted',
    'expected_asset_damage_loss_amount_series_undiscounted',
    'expected_asset_damage_loss_amount_series_discounted',
    'interp_country_productive_capacity_loss'
]]
final_df
# Out:
#        entity_id scenario_code  phys_year country  \
# 0     1008128171        RCP2.6     2023.0     ARE
# 1     1008128171        RCP2.6     2024.0     ARE
# 2     1008128171        RCP2.6     2025.0     ARE
# 3     1008128171        RCP2.6     2026.0     ARE
# 4     1008128171        RCP2.6     2027.0     ARE
# ...          ...           ...        ...     ...
# 1227  1008128171        RCP2.6     2046.0     ZMB
# 1228  1008128171        RCP2.6     2047.0     ZMB
# 1229  1008128171        RCP2.6     2048.0     ZMB
# 1230  1008128171        RCP2.6     2049.0     ZMB
# 1231  1008128171        RCP2.6     2050.0     ZMB
#
#       expected_indirect_loss_amount_series_undiscounted  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1227                                       1.037457e+07
# 1228                                       1.048448e+07
# 1229                                       1.059439e+07
# 1230                                       1.070430e+07
# 1231                                       1.081421e+07
#
#       expected_indirect_loss_amount_series_discounted  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1227                                     1.911507e+06
# 1228                                     1.805381e+06
# 1229                                     1.704960e+06
# 1230                                     1.609951e+06
# 1231                                     1.520076e+06
#
#       expected_revenue_loss_amount_series_undiscounted  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1227                                      44122.828758
# 1228                                      47901.269959
# 1229                                      51679.711161
# 1230                                      55458.152362
# 1231                                      59236.593564
#
#       expected_revenue_loss_amount_series_discounted  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 1227                                     8129.594909
# 1228                                     8248.382797
# 1229                                     8316.834899
# 1230                                     8341.028813
# 1231                                     8326.462363
#
#       expected_asset_damage_loss_amount_series_undiscounted  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1227                                       92325.643515
# 1228                                       96264.028662
# 1229                                      100202.413810
# 1230                                      104140.798957
# 1231                                      108079.184104
#
#       expected_asset_damage_loss_amount_series_discounted  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1227                                       17010.923882
# 1228                                       16576.231875
# 1229                                       16125.611259
# 1230                                       15663.006567
# 1231                                       15191.914399
#
#       interp_country_productive_capacity_loss
# 0                                    0.002724
# 1                                    0.002724
# 2                                    0.002724
# 3                                    0.002724
# 4                                    0.002724
# ...                                       ...
# 1227                                 0.000049
# 1228                                 0.000053
# 1229                                 0.000058
# 1230                                 0.000062
# 1231                                 0.000066
#
# [1232 rows x 11 columns]

# %%
aggregated_df = final_df.groupby(
    ['entity_id', 'scenario_code', 'phys_year']
).agg(
    expected_revenue_loss_amount_series_undiscounted=pd.NamedAgg(column='expected_revenue_loss_amount_series_undiscounted', aggfunc='sum'),
    expected_asset_damage_loss_amount_series_undiscounted=pd.NamedAgg(column='expected_asset_damage_loss_amount_series_undiscounted', aggfunc='sum'),
    expected_indirect_loss_amount_series_undiscounted=pd.NamedAgg(column='expected_indirect_loss_amount_series_undiscounted', aggfunc='sum'),
    expected_revenue_loss_amount_series_discounted=pd.NamedAgg(column='expected_revenue_loss_amount_series_discounted', aggfunc='sum'),
    expected_asset_damage_loss_amount_series_discounted=pd.NamedAgg(column='expected_asset_damage_loss_amount_series_discounted', aggfunc='sum'),
    expected_indirect_loss_amount_series_discounted=pd.NamedAgg(column='expected_indirect_loss_amount_series_discounted', aggfunc='sum')
).reset_index()
aggregated_df.head()
# Out:
#      entity_id scenario_code  phys_year  \
# 0   1008128171        RCP2.6     2023.0
# 1   1008128171        RCP2.6     2024.0
# 2   1008128171        RCP2.6     2025.0
# 3   1008128171        RCP2.6     2026.0
# 4   1008128171        RCP2.6     2027.0
# 5   1008128171        RCP2.6     2028.0
# 6   1008128171        RCP2.6     2029.0
# 7   1008128171        RCP2.6     2030.0
# 8   1008128171        RCP2.6     2031.0
# 9   1008128171        RCP2.6     2032.0
# 10  1008128171        RCP2.6     2033.0
# 11  1008128171        RCP2.6     2034.0
# 12  1008128171        RCP2.6     2035.0
# 13  1008128171        RCP2.6     2036.0
# 14  1008128171        RCP2.6     2037.0
# 15  1008128171        RCP2.6     2038.0
# 16  1008128171        RCP2.6     2039.0
# 17  1008128171        RCP2.6     2040.0
# 18  1008128171        RCP2.6     2041.0
# 19  1008128171        RCP2.6     2042.0
# 20  1008128171        RCP2.6     2043.0
# 21  1008128171        RCP2.6     2044.0
# 22  1008128171        RCP2.6     2045.0
# 23  1008128171        RCP2.6     2046.0
# 24  1008128171        RCP2.6     2047.0
# 25  1008128171        RCP2.6     2048.0
# 26  1008128171        RCP2.6     2049.0
# 27  1008128171        RCP2.6     2050.0
#
#     expected_revenue_loss_amount_series_undiscounted  \
# 0                                       1.397532e+07
# 1                                       1.406028e+07
# 2                                       1.414525e+07
# 3                                       1.421766e+07
# 4                                       1.429006e+07
# 5                                       1.436247e+07
# 6                                       1.443488e+07
# 7                                       1.450729e+07
# 8                                       1.457297e+07
# 9                                       1.463865e+07
# 10                                      1.470433e+07
# 11                                      1.477001e+07
# 12                                      1.483568e+07
# 13                                      1.492404e+07
# 14                                      1.501240e+07
# 15                                      1.510075e+07
# 16                                      1.518911e+07
# 17                                      1.527747e+07
# 18                                      1.539425e+07
# 19                                      1.551104e+07
# 20                                      1.562783e+07
# 21                                      1.574462e+07
# 22                                      1.586140e+07
# 23                                      1.598377e+07
# 24                                      1.610613e+07
# 25                                      1.622850e+07
# 26                                      1.635086e+07
# 27                                      1.647323e+07
#
#     expected_asset_damage_loss_amount_series_undiscounted  \
# 0                                        2.849498e+07
# 1                                        2.853672e+07
# 2                                        2.857846e+07
# 3                                        2.860469e+07
# 4                                        2.863091e+07
# 5                                        2.865713e+07
# 6                                        2.868336e+07
# 7                                        2.870958e+07
# 8                                        2.873702e+07
# 9                                        2.876446e+07
# 10                                       2.879191e+07
# 11                                       2.881935e+07
# 12                                       2.884679e+07
# 13                                       2.888934e+07
# 14                                       2.893189e+07
# 15                                       2.897445e+07
# 16                                       2.901700e+07
# 17                                       2.905955e+07
# 18                                       2.912158e+07
# 19                                       2.918361e+07
# 20                                       2.924564e+07
# 21                                       2.930767e+07
# 22                                       2.936970e+07
# 23                                       2.943630e+07
# 24                                       2.950290e+07
# 25                                       2.956949e+07
# 26                                       2.963609e+07
# 27                                       2.970269e+07
#
#     expected_indirect_loss_amount_series_undiscounted  \
# 0                                        3.271117e+07
# 1                                        3.326837e+07
# 2                                        3.382556e+07
# 3                                        3.431520e+07
# 4                                        3.480484e+07
# 5                                        3.529447e+07
# 6                                        3.578410e+07
# 7                                        3.627373e+07
# 8                                        3.680213e+07
# 9                                        3.733052e+07
# 10                                       3.785891e+07
# 11                                       3.838729e+07
# 12                                       3.891566e+07
# 13                                       3.937138e+07
# 14                                       3.982710e+07
# 15                                       4.028281e+07
# 16                                       4.073851e+07
# 17                                       4.119420e+07
# 18                                       4.164146e+07
# 19                                       4.208871e+07
# 20                                       4.253596e+07
# 21                                       4.298319e+07
# 22                                       4.343042e+07
# 23                                       4.391278e+07
# 24                                       4.439514e+07
# 25                                       4.487748e+07
# 26                                       4.535981e+07
# 27                                       4.584213e+07
#
#     expected_revenue_loss_amount_series_discounted  \
# 0                                     1.220658e+07
# 1                                     1.147738e+07
# 2                                     1.079134e+07
# 3                                     1.013699e+07
# 4                                     9.522073e+06
# 5                                     8.944225e+06
# 6                                     8.401231e+06
# 7                                     7.891003e+06
# 8                                     7.408157e+06
# 9                                     6.954715e+06
# 10                                    6.528897e+06
# 11                                    6.129027e+06
# 12                                    5.753534e+06
# 13                                    5.409159e+06
# 14                                    5.085219e+06
# 15                                    4.780512e+06
# 16                                    4.493910e+06
# 17                                    4.224347e+06
# 18                                    3.978168e+06
# 19                                    3.746120e+06
# 20                                    3.527407e+06
# 21                                    3.321278e+06
# 22                                    3.127022e+06
# 23                                    2.944996e+06
# 24                                    2.773403e+06
# 25                                    2.611658e+06
# 26                                    2.459206e+06
# 27                                    2.315523e+06
#
#     expected_asset_damage_loss_amount_series_discounted  \
# 0                                        2.488862e+07
# 1                                        2.329447e+07
# 2                                        2.180237e+07
# 3                                        2.039475e+07
# 4                                        1.907798e+07
# 5                                        1.784622e+07
# 6                                        1.669397e+07
# 7                                        1.561611e+07
# 8                                        1.460845e+07
# 9                                        1.366579e+07
# 10                                       1.278395e+07
# 11                                       1.195901e+07
# 12                                       1.118728e+07
# 13                                       1.047083e+07
# 14                                       9.800234e+06
# 15                                       9.172568e+06
# 16                                       8.585083e+06
# 17                                       8.035208e+06
# 18                                       7.525570e+06
# 19                                       7.048224e+06
# 20                                       6.601126e+06
# 21                                       6.182362e+06
# 22                                       5.790137e+06
# 23                                       5.423614e+06
# 24                                       5.080266e+06
# 25                                       4.758629e+06
# 26                                       4.457333e+06
# 27                                       4.175093e+06
#
#     expected_indirect_loss_amount_series_discounted
# 0                                      2.857120e+07
# 1                                      2.715690e+07
# 2                                      2.580536e+07
# 3                                      2.446627e+07
# 4                                      2.319193e+07
# 5                                      2.197962e+07
# 6                                      2.082667e+07
# 7                                      1.973050e+07
# 8                                      1.870833e+07
# 9                                      1.773546e+07
# 10                                     1.680981e+07
# 11                                     1.592936e+07
# 12                                     1.509216e+07
# 13                                     1.427000e+07
# 14                                     1.349082e+07
# 15                                     1.275250e+07
# 16                                     1.205305e+07
# 17                                     1.139054e+07
# 18                                     1.076095e+07
# 19                                     1.016498e+07
# 20                                     9.600926e+06
# 21                                     9.067170e+06
# 22                                     8.562160e+06
# 23                                     8.090894e+06
# 24                                     7.644642e+06
# 25                                     7.222149e+06
# 26                                     6.822215e+06
# 27                                     6.443698e+06

# %%
aggregated_df['expected_direct_damage_loss_amount_series_undiscounted'] = (
    aggregated_df['expected_revenue_loss_amount_series_undiscounted'] + 
    aggregated_df['expected_asset_damage_loss_amount_series_undiscounted']
)

aggregated_df['expected_direct_damage_loss_amount_series_discounted'] = (
    aggregated_df['expected_revenue_loss_amount_series_discounted'] + 
    aggregated_df['expected_asset_damage_loss_amount_series_discounted']
)

aggregated_df['expected_total_loss_amount_series_undiscounted'] = (
    aggregated_df['expected_direct_damage_loss_amount_series_undiscounted'] + 
    aggregated_df['expected_indirect_loss_amount_series_undiscounted']
)

aggregated_df['expected_total_loss_amount_series_discounted'] = (
    aggregated_df['expected_direct_damage_loss_amount_series_discounted'] + 
    aggregated_df['expected_indirect_loss_amount_series_discounted'] )

aggregated_df = aggregated_df.sort_values(by=['entity_id', 'scenario_code', 'phys_year'])

# %%
aggregated_df = aggregated_df.rename(columns = {"scenario_code" :"rcp_scenario", "phys_year" : "physical_impact_year"
})
aggregated_df['physical_impact_year'] = aggregated_df['physical_impact_year'].astype(int)

# %%
damage_df = aggregated_df[["entity_id","rcp_scenario","physical_impact_year","expected_revenue_loss_amount_series_undiscounted","expected_asset_damage_loss_amount_series_undiscounted","expected_direct_damage_loss_amount_series_undiscounted","expected_indirect_loss_amount_series_undiscounted","expected_revenue_loss_amount_series_discounted","expected_asset_damage_loss_amount_series_discounted","expected_direct_damage_loss_amount_series_discounted","expected_indirect_loss_amount_series_discounted","expected_total_loss_amount_series_undiscounted","expected_total_loss_amount_series_discounted"]]

# %%
damage_df.head()
# Out:
#     entity_id rcp_scenario  physical_impact_year  \
# 0  1008128171       RCP2.6                  2023
# 1  1008128171       RCP2.6                  2024
# 2  1008128171       RCP2.6                  2025
# 3  1008128171       RCP2.6                  2026
# 4  1008128171       RCP2.6                  2027
#
#    expected_revenue_loss_amount_series_undiscounted  \
# 0                                      1.397532e+07
# 1                                      1.406028e+07
# 2                                      1.414525e+07
# 3                                      1.421766e+07
# 4                                      1.429006e+07
#
#    expected_asset_damage_loss_amount_series_undiscounted  \
# 0                                       2.849498e+07
# 1                                       2.853672e+07
# 2                                       2.857846e+07
# 3                                       2.860469e+07
# 4                                       2.863091e+07
#
#    expected_direct_damage_loss_amount_series_undiscounted  \
# 0                                       4.247030e+07
# 1                                       4.259701e+07
# 2                                       4.272371e+07
# 3                                       4.282234e+07
# 4                                       4.292097e+07
#
#    expected_indirect_loss_amount_series_undiscounted  \
# 0                                       3.271117e+07
# 1                                       3.326837e+07
# 2                                       3.382556e+07
# 3                                       3.431520e+07
# 4                                       3.480484e+07
#
#    expected_revenue_loss_amount_series_discounted  \
# 0                                    1.220658e+07
# 1                                    1.147738e+07
# 2                                    1.079134e+07
# 3                                    1.013699e+07
# 4                                    9.522073e+06
#
#    expected_asset_damage_loss_amount_series_discounted  \
# 0                                       2.488862e+07
# 1                                       2.329447e+07
# 2                                       2.180237e+07
# 3                                       2.039475e+07
# 4                                       1.907798e+07
#
#    expected_direct_damage_loss_amount_series_discounted  \
# 0                                       3.709521e+07
# 1                                       3.477185e+07
# 2                                       3.259371e+07
# 3                                       3.053174e+07
# 4                                       2.860006e+07
#
#    expected_indirect_loss_amount_series_discounted  \
# 0                                     2.857120e+07
# 1                                     2.715690e+07
# 2                                     2.580536e+07
# 3                                     2.446627e+07
# 4                                     2.319193e+07
#
#    expected_total_loss_amount_series_undiscounted  \
# 0                                    7.518147e+07
# 1                                    7.586537e+07
# 2                                    7.654927e+07
# 3                                    7.713754e+07
# 4                                    7.772581e+07
#
#    expected_total_loss_amount_series_discounted
# 0                                  6.566641e+07
# 1                                  6.192874e+07
# 2                                  5.839907e+07
# 3                                  5.499800e+07
# 4                                  5.179199e+07

# %%
damage_df.to_csv('calculated_damage.csv',index=False)

# %% [markdown]
# ## Testing

# %%
# interp_country_indirect_probability_set = interp_country_indirect_probability_set.rename( columns = { 'phys_year'})
# interp_country_indirect_probability_set.head()

# %%
# ff = df.copy()
# ff = ff.merge(interp_country_indirect_probability_set, on=['entity_id','scenario_code','country','phys_year'])
# ff
# ff['expected_indirect_loss_amount_series_undiscounted'] = np.where(
#     (ff['revenue_avg_usd'] < 0) | (ff['gppe_avg_usd'] < 0) | (ff['avg_country_revenue_usd'] < 0), 
#     np.nan, 
#     ff['interp_indirect_probability'] * ff['avg_country_revenue_usd']
# )

# %%
# ff[ff['phys_year']==2023] [['entity_id', 'scenario_code', 'phys_year','country','avg_country_revenue_usd']]

# %%
# ff.groupby(
#     ['entity_id', 'scenario_code', 'phys_year'], as_index=False
# ).agg(expected_indirect_loss_amount_series_undiscounted = ('expected_indirect_loss_amount_series_undiscounted','sum'))#['expected_indirect_loss_amount_series_undiscounted'][0]

# %%
# 3162741.531455139073 -3162741.6333086947
